# %% [markdown]
# <a href="https://colab.research.google.com/github/choisooyeon007/hello-world/blob/master/COVID19_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ed809d2c-2959-4a6f-97ae-4e8785d1741d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed809d2c-2959-4a6f-97ae-4e8785d1741d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("test.csv")
df.head()
# Out:
#         행 레이블     0      1      2   ...  20 .76  21 .76  22 .76  23 .76
# 0  11110515.0  -2.85  -2.74  -2.75  ...    4.32    4.69    6.35    0.45
# 1  11110530.0 -25.48 -23.48 -22.75  ...  -34.05  -30.66  -28.69  -23.29
# 2  11110540.0  13.38  14.58  12.54  ...  -13.48   -6.59   -5.04   -2.77
# 3  11110550.0  32.82  31.58  31.69  ...   17.08   15.12   15.10   16.79
# 4  11110560.0  -7.49  -7.92  -8.62  ...   -0.01   -4.26   -4.49  -10.53
#
# [5 rows x 1945 columns]

# %%
df1=np.transpose(df)
df1
# Out:
#                 0            1            2    ...          422          423  424
# 행 레이블   11110515.00  11110530.00  11110540.00  ...  11740690.00  11740700.00  NaN
# 0             -2.85       -25.48        13.38  ...       -10.10        -2.61  NaN
# 1             -2.74       -23.48        14.58  ...       -12.73        -2.84  NaN
# 2             -2.75       -22.75        12.54  ...       -12.50        -2.34  NaN
# 3             -2.82       -25.47        11.14  ...       -12.15        -2.13  NaN
# ...             ...          ...          ...  ...          ...          ...  ...
# 19 .76         2.20       -35.80       -17.79  ...       -19.48        -4.69  NaN
# 20 .76         4.32       -34.05       -13.48  ...       -19.35        -3.63  NaN
# 21 .76         4.69       -30.66        -6.59  ...       -19.28        -0.10  NaN
# 22 .76         6.35       -28.69        -5.04  ...       -19.64         0.76  NaN
# ...

# %%
df2=df1.drop(['행 레이블'])
df2
# Out:
#          0      1      2      3      4    ...    420    421    422   423  424
# 0      -2.85 -25.48  13.38  32.82  -7.49  ... -18.08 -13.01 -10.10 -2.61  NaN
# 1      -2.74 -23.48  14.58  31.58  -7.92  ... -18.82 -13.09 -12.73 -2.84  NaN
# 2      -2.75 -22.75  12.54  31.69  -8.62  ... -18.72 -13.46 -12.50 -2.34  NaN
# 3      -2.82 -25.47  11.14  31.52  -8.98  ... -18.79 -13.25 -12.15 -2.13  NaN
# 4      -3.04 -24.34  10.46  31.13  -9.17  ... -18.93 -12.80 -10.79 -1.32  NaN
# ...      ...    ...    ...    ...    ...  ...    ...    ...    ...   ...  ...
# 19 .76  2.20 -35.80 -17.79  14.78   2.08  ...  -5.58  -4.78 -19.48 -4.69  NaN
# 20 .76  4.32 -34.05 -13.48  17.08  -0.01  ...  -7.76  -5.08 -19.35 -3.63  NaN
# 21 .76  4.69 -30.66  -6.59  15.12  -4.26  ... -10.23  -5.46 -19.28 -0.10  NaN
# 22 .76  6.35 -28.69  -5.04  15.10  -4.49  ... -12.78  -6.16 -19.64  0.76  NaN
# 23 .76  0.45 -23.29  -2.77  16.79 -10.53  ... -11.47 -12.70 -16.76 -0.94  NaN
#
# [1944 rows x 425 columns]

# %%
df2.plot()
plt.figure(figsize=(100,100))
plt.show()
