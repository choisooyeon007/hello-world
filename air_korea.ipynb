# %% [markdown]
# <a href="https://colab.research.google.com/github/choisooyeon007/hello-world/blob/master/air_korea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()

df=pd.read_csv('gangdong_sep.csv')
# Out:
#      <input type="file" id="files-69d7fde6-a0fc-4782-9633-e6b19dbbfa21" name="files[]" multiple disabled />
#      <output id="result-69d7fde6-a0fc-4782-9633-e6b19dbbfa21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
df.rename(columns={'날짜_시간':'Date_Time'}, inplace=True)
print(df.shape)
df.head()
# Out:
# (720, 10)
#        Date_Time       시도 측정소명   측정소코드  아황산가스  일산화탄소     오존  이산화질소  PM10  PM2.5
# 0  2019-09-01 01  서울 강동구   강동구  111274  0.003    0.5  0.005  0.040   NaN   15.0
# 1  2019-09-01 02  서울 강동구   강동구  111274  0.003    0.5  0.006  0.034   NaN   15.0
# 2  2019-09-01 03  서울 강동구   강동구  111274  0.003    0.5  0.007  0.030  30.0   15.0
# 3  2019-09-01 04  서울 강동구   강동구  111274  0.003    0.5  0.012  0.020  29.0   14.0
# 4  2019-09-01 05  서울 강동구   강동구  111274  0.003    0.5  0.014  0.016  22.0   11.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.dates as mdates

# %%
df1=df.drop(["Date_Time",	"시도",	"측정소명",	"측정소코드"], axis='columns')
df1.columns=['SO2','CO',"O3",'NO2',"PM10","PM2.5"]
df1.head()
# Out:
#      SO2   CO     O3    NO2  PM10  PM2.5
# 0  0.003  0.5  0.005  0.040   NaN   15.0
# 1  0.003  0.5  0.006  0.034   NaN   15.0
# 2  0.003  0.5  0.007  0.030  30.0   15.0
# 3  0.003  0.5  0.012  0.020  29.0   14.0
# 4  0.003  0.5  0.014  0.016  22.0   11.0

# %%
df2=df1.drop(["SO2","CO"], axis='columns')
df2.head()
# Out:
#       O3    NO2  PM10  PM2.5
# 0  0.005  0.040   NaN   15.0
# 1  0.006  0.034   NaN   15.0
# 2  0.007  0.030  30.0   15.0
# 3  0.012  0.020  29.0   14.0
# 4  0.014  0.016  22.0   11.0

# %%
import pylab

# %%
dates=pd.date_range('2019-09-01 00', periods=30, freq='D')
dates
# Out:
# DatetimeIndex(['2019-09-01', '2019-09-02', '2019-09-03', '2019-09-04',
#                '2019-09-05', '2019-09-06', '2019-09-07', '2019-09-08',
#                '2019-09-09', '2019-09-10', '2019-09-11', '2019-09-12',
#                '2019-09-13', '2019-09-14', '2019-09-15', '2019-09-16',
#                '2019-09-17', '2019-09-18', '2019-09-19', '2019-09-20',
#                '2019-09-21', '2019-09-22', '2019-09-23', '2019-09-24',
#                '2019-09-25', '2019-09-26', '2019-09-27', '2019-09-28',
#                '2019-09-29', '2019-09-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
X=df.iloc[:,0]
Y=df.iloc[:,8]
plt.xlabel(df.columns[0])
plt.ylabel(df.columns[8])

plt.xticks(np.linspace(0,719,4,endpoint=True))
plt.plot(X,Y, c='m')
plt.show()

# %%
X=df2.iloc[:,0]
Y=df2.iloc[:,1]
plt.xlabel(df2.columns[0])
plt.ylabel(df2.columns[1])
plt.scatter(X,Y)
plt.figure(figsize=(10,7))
plt.show()

# %%
sns.pairplot(df2)
plt.title("Air pairplot")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
