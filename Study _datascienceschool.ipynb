# %% [markdown]
# <a href="https://colab.research.google.com/github/choisooyeon007/hello-world/blob/master/Study%20_datascienceschool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
iris = load_iris()
print(iris.DESCR)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names )
#print(df)
sy = pd.Series(iris.target, dtype="category")
#print(sy)
sy=sy.cat.rename_categories(iris.target_names)
#print(sy)
df['species']=sy
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                5.1               3.5  ...               0.2   setosa
# 1                4.9               3.0  ...               0.2   setosa
# 2                4.7               3.2  ...               0.2   setosa
# 3                4.6               3.1  ...               0.2   setosa
# 4                5.0               3.6  ...               0.2   setosa
#
# [5 rows x 5 columns]

# %%
sns.pairplot(df,hue='species')
plt.show()

# %%
sns.distplot(df[df.species == "setosa"]["petal length (cm)"], rug=True, label="setosa")
sns.distplot(df[df.species != "setosa"]["petal length (cm)"], rug=True, label="others")
plt.legend()
plt.show()

# %%
sns.distplot(df[df.species == "virginica"]["petal length (cm)"], hist=True, rug=True, label="virginica")
sns.distplot(df[df.species == "versicolor"]["petal length (cm)"], hist=True, rug=True, label="versicolor")
plt.legend()
plt.show()

# %%
from sklearn.datasets import load_wine
wine = load_wine()
print(wine.DESCR)

# %%
wine.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']
