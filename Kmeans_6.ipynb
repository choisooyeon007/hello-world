# %% [markdown]
# <a href="https://colab.research.google.com/github/choisooyeon007/hello-world/blob/master/Kmeans_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3eecdc6a-0b8a-430a-88c7-8a711be9e039" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3eecdc6a-0b8a-430a-88c7-8a711be9e039">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid 27Jul.csv to covid 27Jul (1).csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

# %%
df=pd.read_csv("covid 27Jul (1).csv")
df.head()
# Out:
#        dong  2020-01-02 0:00  ...  2020-03-22 22:00  2020-03-22 23:00
# 0  11110515            -2.85  ...              6.35              0.45
# 1  11110530           -25.48  ...            -28.69            -23.29
# 2  11110540            13.38  ...             -5.04             -2.77
# 3  11110550            32.82  ...             15.10             16.79
# 4  11110560            -7.49  ...             -4.49            -10.53
#
# [5 rows x 1945 columns]

# %%
df=df.dropna(axis=1)
df.head()
# Out:
#        dong  2020-01-02 0:00  ...  2020-03-22 22:00  2020-03-22 23:00
# 0  11110515            -2.85  ...              6.35              0.45
# 1  11110530           -25.48  ...            -28.69            -23.29
# 2  11110540            13.38  ...             -5.04             -2.77
# 3  11110550            32.82  ...             15.10             16.79
# 4  11110560            -7.49  ...             -4.49            -10.53
#
# [5 rows x 1849 columns]

# %%
df1=df.set_index('dong')
df1.head()
# Out:
#           2020-01-02 0:00  2020-01-02 1:00  ...  2020-03-22 22:00  2020-03-22 23:00
# dong                                        ...
# 11110515            -2.85            -2.74  ...              6.35              0.45
# 11110530           -25.48           -23.48  ...            -28.69            -23.29
# 11110540            13.38            14.58  ...             -5.04             -2.77
# 11110550            32.82            31.58  ...             15.10             16.79
# 11110560            -7.49            -7.92  ...             -4.49            -10.53
#
# [5 rows x 1848 columns]

# %%
#df1.index.astype('object')
#df1.columns=pd.to_datetime(df1.columns)
#df1.dtypes

# %%
ks = range(1,10)
inertias = []
for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(df1.values)
    inertias.append(model.inertia_)
# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
kmeans=KMeans(n_clusters=6).fit(df1.values)
kmeans.inertia_
# Out:
# 41305450.105539426

# %%
kmeans.labels_
df1['cluster']=kmeans.labels_
df1.head()
# Out:
#           2020-01-02 00:00:00  ...  cluster
# dong                           ...
# 11110515                -2.85  ...        5
# 11110530               -25.48  ...        0
# 11110540                13.38  ...        0
# 11110550                32.82  ...        2
# 11110560                -7.49  ...        5
#
# [5 rows x 1849 columns]

# %%
df00=df1[df1['cluster']==0]
df01=df1[df1['cluster']==1]
df02=df1[df1['cluster']==2]
df03=df1[df1['cluster']==3]
df04=df1[df1['cluster']==4]
df05=df1[df1['cluster']==5]

# %%
plt.figure(figsize=(10,20))

plt.subplot(3,2,1)
plt.ylim(-100,200)
plt.xlabel('date')
plt.ylabel('change rate')
plt.title('group 0')
plt.plot(df00, label=df00.index) 
plt.grid()
#plt.legend(df00.index, title='group0', ncol=5)

plt.subplot(3,2,2)
plt.ylim(-100,200)
plt.xlabel('date')
plt.ylabel('change rate')
plt.title('group 1')
plt.plot(df01, label=df01.index) 
plt.grid()
#plt.legend(df01.index, title='group1',ncol=5)


plt.subplot(3,2,3)
plt.ylim(-100,200)
plt.xlabel('date')
plt.ylabel('change rate')
plt.title('group 2')
plt.plot(df02, label=df2.index) 
plt.grid()
#plt.legend(df02.index, title='group2',ncol=5)

plt.subplot(3,2,4)
plt.ylim(-100,200)
plt.xlabel('date')
plt.ylabel('change rate')
plt.title('group 3')
plt.plot(df03, label=df03.index) 
plt.grid()
#plt.legend(df03.index, title='group3', ncol=5)

plt.subplot(3,2,5)
plt.ylim(-100,200)
plt.xlabel('date')
plt.ylabel('change rate')
plt.title('group 4')
plt.plot(df04, label=df04.index) 
plt.grid()
#plt.legend(df04.index, title='group4', ncol=5)

plt.subplot(3,2,6)
plt.ylim(-100,200)
plt.xlabel('date')
plt.ylabel('change rate')
plt.title('group 5')
plt.plot(df05, label=df05.index) 
plt.grid()
#plt.legend(df05.index, title='group5',ncol=5)

plt.show()
