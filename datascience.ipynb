# %% [markdown]
# <a href="https://colab.research.google.com/github/choisooyeon007/hello-world/blob/master/datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

a=np.arange(3)
b=np.arange(4)
#print(a)
#print(b)
A,B=np.meshgrid(a,b)
print(A)
print(B)
[list(zip(a, b)) for a, b in zip(A, B)]
plt.scatter(A, B, linewidths=5, c='g')
plt.show()
# Out:
# [[0 1 2]
#  [0 1 2]
#  [0 1 2]
#  [0 1 2]]
# [[0 0 0]
#  [1 1 1]
#  [2 2 2]
#  [3 3 3]]

# %%
np.random.choice(3, size=10, replace=True, p=[0.1,0.7,0.2])
# Out:
# array([2, 0, 2, 2, 1, 2, 1, 1, 1, 1])

# %%
import pandas as pd

# %%
data = {
    "2015": [9904312, 3448737, 2890451, 2466052],
    "2010": [9631482, 3393191, 2632035, 2431774],
    "2005": [9762546, 3512547, 2517680, 2456016],
    "2000": [9853972, 3655437, 2466338, 2473990],
    "지역": ["수도권", "경상권", "수도권", "경상권"],
    "2010-2015 증가율": [0.0283, 0.0163, 0.0982, 0.0141]
}
columns = ["지역", "2015", "2010", "2005", "2000", "2010-2015 증가율"]
index = ["서울", "부산", "인천", "대구"]
df = pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#      지역     2015     2010     2005     2000  2010-2015 증가율
# 서울  수도권  9904312  9631482  9762546  9853972         0.0283
# 부산  경상권  3448737  3393191  3512547  3655437         0.0163
# 인천  수도권  2890451  2632035  2517680  2466338         0.0982
# 대구  경상권  2466052  2431774  2456016  2473990         0.0141

# %%
# %%writefile sample1.csv
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Writing sample1.csv

# %%
pd.read_csv('sample1.csv', index_col='c1')
# Out:
#       c2      c3
# c1
# 1   1.11     one
# 2   2.22     two
# 3   3.33   three

# %%
# %%writefile sample3.txt
# c1        c2        c3        c4
# 0.179181 -1.538472  1.347553  0.43381
# 1.024209  0.087307 -1.281997  0.49265
# 0.417899 -2.002308  0.255245 -1.10515
# Out:
# Writing sample3.txt

# %%
pd.read_table('sample3.txt', sep='\s+')
# Out:
#          c1        c2        c3       c4
# 0  0.179181 -1.538472  1.347553  0.43381
# 1  1.024209  0.087307 -1.281997  0.49265
# 2  0.417899 -2.002308  0.255245 -1.10515

# %%
# %%writefile sample5.csv
# c1, c2, c3
# 1, 1.11, one
# 2, , two
# 누락, 3.33, three
# Out:
# Writing sample5.csv

# %%
df=pd.read_csv('sample5.csv', index_col=[0], na_values=['누락'])
df
# Out:
#     c1     c2      c3
# 0  1.0   1.11     one
# 1  2.0            two
# 2  NaN   3.33   three

# %%
df.to_csv('sample6.csv')

# %%
cat sample6.csv
# Out:
# ,c1, c2, c3
# 0,1.0, 1.11, one
# 1,2.0, , two
# 2,, 3.33, three

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datascienceschool/docker_rpython/master/data/titanic.csv")
pd.set_option("display.max_rows",20)
df.head()
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [3 rows x 12 columns]

# %%
import datetime
dt_start=datetime.datetime(2015,1,1)
dt_end="2016,6,30"

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff0775fa-3cb6-459f-835c-feea69f74be3" name="files[]" multiple disabled />
#      <output id="result-ff0775fa-3cb6-459f-835c-feea69f74be3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving GDP.csv to GDP (1).csv

# %%
import io
df=pd.read_csv('GDP.csv')
print(df.head())
df.shape
# Out:
#          DATE      GDP
# 0  1947-01-01  243.164
# 1  1947-04-01  245.968
# 2  1947-07-01  249.585
# 3  1947-10-01  259.745
# 4  1948-01-01  265.742
# (291, 2)

# %%
df=pd.DataFrame(np.arange(10,30).reshape(5,4), index=["a","b","c","d","e"], columns=["A","B","C","D"])
print(df)
df.iloc[2:3]
df.count()
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21
# d  22  23  24  25
# e  26  27  28  29
# A    5
# B    5
# C    5
# D    5
# dtype: int64

# %%
df=pd.DataFrame(np.random.randint(5,size=(4,4)))
df
df.iloc[2,3]=np.nan
print(df)
df.count()
# Out:
#    0  1  2    3
# 0  1  3  0  2.0
# 1  2  0  3  0.0
# 2  3  4  0  NaN
# 3  3  0  0  1.0
# 0    4
# 1    4
# 2    4
# 3    3
# dtype: int64

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
print(titanic.tail())

titanic['age'].value_counts()
titanic['sex'].value_counts()
titanic['class'].value_counts()
titanic['alive'].value_counts()
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [5 rows x 15 columns]
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
s=pd.Series(np.random.randint(10,size=100))
s.tail()
s.value_counts()
# Out:
# 4    15
# 2    14
# 9    11
# 7    10
# 6     9
# 5     9
# 3     9
# 0     9
# 8     7
# 1     7
# dtype: int64

# %%
df=pd.DataFrame(np.arange(10,30).reshape(5,4), index=["a","b","c","d","e"], columns=["A","B","C","D"])
print(df)
# Out:
#     A   B   C   D
# a  10  11  12  13
# b  14  15  16  17
# c  18  19  20  21
# d  22  23  24  25
# e  26  27  28  29

# %%
ages = [0, 2, 10, 21, 23, 37, 31, 61, 20, 41, 32, 100]
bins = [1, 15, 25, 35, 60, 99]
labels = ["under", "young", "middle", "mature", "old"]
cats = pd.cut(ages, bins, labels=labels)
cats
df=pd.DataFrame(ages,columns=['ages'])
df['ages_cat']=pd.cut(ages, bins, labels=labels)
print(df)
df=pd.qcut(ages, 4,labels=["Q1","Q2","Q3","Q4"])
df
pd.value_counts(df)
# Out:
#     ages ages_cat
# 0      0      NaN
# 1      2    under
# 2     10    under
# 3     21    young
# 4     23    young
# 5     37   mature
# 6     31   middle
# 7     61      old
# 8     20    young
# 9     41   mature
# 10    32   middle
# 11   100      NaN
# Q4    3
# Q3    3
# Q2    3
# Q1    3
# dtype: int64

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datascienceschool/docker_rpython/master/data/titanic.csv")

# %%
print(df.head())
df1=df.sort_values(by='Survived')
df1
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]
#      PassengerId  Survived  Pclass  ...      Fare Cabin  Embarked
# 0              1         0       3  ...    7.2500   NaN         S
# 519          520         0       3  ...    7.8958   NaN         S
# 521          522         0       3  ...    7.8958   NaN         S
# 522          523         0       3  ...    7.2250   NaN         C
# 524          525         0       3  ...    7.2292   NaN         C
# ..           ...       ...     ...  ...       ...   ...       ...
# 546          547         1       2  ...   26.0000   NaN         S
# ...

# %%
data = {
    "도시": ["서울", "서울", "서울", "부산", "부산", "부산", "인천", "인천"],
    "연도": ["2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"],
    "인구": [9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 263203],
    "지역": ["수도권", "수도권", "수도권", "경상권", "경상권", "경상권", "수도권", "수도권"]
}
columns = ["도시", "연도", "인구", "지역"]
df1 = pd.DataFrame(data, columns=columns)
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010   263203  수도권

# %%
df1.pivot("도시","연도","인구")
# Out:
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN   263203.0  2890451.0

# %%
tips = sns.load_dataset("tips")
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips['tip_pct']=tips['tip']/tips['total_bill']
print(tips.tail())
print(tips.groupby(['sex','smoker']))
tips.pivot_table("tip_pct",'sex','smoker', aggfunc="mean", margins=True)
tips.pivot_table("tip_pct",'day','size', aggfunc="mean", margins=True)
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
# ...
# size         1         2         3         4         5         6       All
# day
# Thur  0.181728  0.163935  0.144599  0.145515  0.121389  0.173706  0.161276
# Fri   0.223776  0.168693  0.187735  0.117750       NaN       NaN  0.169913
# Sat   0.231832  0.155289  0.151439  0.138289  0.106572       NaN  0.153152
# Sun        NaN  0.180870  0.152662  0.153168  0.159839  0.103799  0.166897
# All   0.217292  0.165719  0.152157  0.145949  0.141495  0.156229  0.160803

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

# %%
plt.title("Plot", fontdict={'size':20, 'c':'pink'})
plt.plot([1, 4, 9, 16])
plt.show()

# %%
plt.title("multiple line")
plt.plot([1, 4, 9, 16],
         c="m", lw=5, ls="--", marker="o", ms=10, mfc="r", label="haha")
plt.plot([9, 16, 4, 1],
         c="c", lw=3, ls="-.", marker="s", ms=10, mfc="b", label="kiki")
plt.legend(loc=0)
plt.show()

# %%
np.random.seed(10)
f1 = plt.figure(figsize=(10, 4))
plt.title("soo")
plt.plot(np.random.randn(100))
plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.figure(figsize=(50,50))
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
fig, axes = plt.subplots(2, 3)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")
axes[0,2].plot(np.random.rand(5))
axes[0, 2].set_title("axes 5")
axes[1,2].plot(np.random.rand(5))
axes[1, 2].set_title("axes 6")

plt.tight_layout()
plt.show()

# %%
y = [2, 3, 1]
x = np.arange(len(y))
print(x)

plt.yticks(sorted(y))
plt.bar(x, y)
# Out:
# [0 1 2]
# <BarContainer object of 3 artists>

# %%
np.random.seed(0)

people = ['A', 'B', 'C', 'D']
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(y_pos, performance, xerr=error, alpha=0.4)
plt.yticks(y_pos, people)
plt.xlabel('x ')
plt.show()

# %%
x = np.linspace(0.1, 2 * np.pi, 10)
plt.title("Stem Plot")
plt.stem(x, np.cos(x), '-.')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
labels = ['frog', 'pig', 'dog', 'log']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'magenta', 'cyan']
explode = (0, 0, 0.1, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title("Histogram")
arrays, bins, patches = plt.hist(x, bins=20)
plt.show()
print(arrays)
bins
# Out:
# [  3.   6.   9.  11.  30.  40.  59.  87. 103. 114. 116. 123.  83.  77.
#   48.  38.  22.  16.  11.   4.]
# array([-3.04614305, -2.75586815, -2.46559324, -2.17531833, -1.88504342,
#        -1.59476851, -1.3044936 , -1.0142187 , -0.72394379, -0.43366888,
#        -0.14339397,  0.14688094,  0.43715585,  0.72743075,  1.01770566,
#         1.30798057,  1.59825548,  1.88853039,  2.1788053 ,  2.46908021,
#         2.75935511])

# %%
np.random.seed(0)
X = np.random.normal(0, 2, 100)
Y = np.random.normal(0, 2, 100)
plt.title("Scatter Plot")
plt.scatter(X, Y)
plt.show()

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %%
from sklearn.datasets import load_digits

# %%
X = load_digits().images[7]
X
# Out:
# array([[ 0.,  0.,  7.,  8., 13., 16., 15.,  1.],
#        [ 0.,  0.,  7.,  7.,  4., 11., 12.,  0.],
#        [ 0.,  0.,  0.,  0.,  8., 13.,  1.,  0.],
#        [ 0.,  4.,  8.,  8., 15., 15.,  6.,  0.],
#        [ 0.,  2., 11., 15., 15.,  4.,  0.,  0.],
#        [ 0.,  0.,  0., 16.,  5.,  0.,  0.,  0.],
#        [ 0.,  0.,  9., 15.,  1.,  0.,  0.,  0.],
#        [ 0.,  0., 13.,  5.,  0.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 7")
plt.imshow(X,interpolation='nearest', cmap=plt.cm.BuPu_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.figure(figsize=(50,50))
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 3))
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(X, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(X, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title("plt.BrBG")
axes[2].imshow(X, interpolation='nearest', cmap='BrBG')
axes[3].set_title("plt.BrBG_r")
axes[3].imshow(X, interpolation='nearest', cmap='BrBG_r')
plt.figure(figsize=(50,50))
plt.show()

# %%
methods = [
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
    'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
    'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos'
]
fig, axes = plt.subplots(3, 6, figsize=(12, 6),
                         subplot_kw={'xticks': [], 'yticks': []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap=plt.cm.bone_r, interpolation=interp_method)
    ax.set_title(interp_method)
plt.show()

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")
plt.contourf(XX, YY, ZZ, alpha=.5, cmap='jet')
plt.contour(XX, YY, ZZ, colors='cyan')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-10, 10, 0.5)
Y = np.arange(-10, 10, 0.5)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, rstride=1, cstride=1, cmap='jet')
plt.show()

# %%
iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터
tips = sns.load_dataset("tips")    # 팁 데이터
flights = sns.load_dataset("flights")    # 여객운송 데이터

# %%
x = iris.petal_length.values

sns.rugplot(x)
plt.title("Iris PL")
plt.show()

# %%
sns.kdeplot(x)
plt.title("Iris  Kernel Density Plot")
plt.show()

# %%
sns.distplot(x, kde=True, rug=True)
plt.title("Iris  Dist Plot")
plt.show()

# %%
sns.countplot(x="class", data=titanic)
plt.title("titanic")
plt.show()
